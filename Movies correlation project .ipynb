# %% [markdown]
# ### About the project

# %% [markdown]
# ###### The aim of this work is to explore  the relationships between the gross income and various factors such as movie score, number of votes, budget, and more. This dataset was sourced from Kaggle and comprises 7,668 rows and 15 columns. Among these columns, there are 14 independent variables and one target variable, which is the gross income.

# %% [markdown]
# ### Data Dictionary

# %%
df=pd.read_csv(r"C:\Users\maram\Downloads\movies.csv")
df.head(2)
# Out:
#               name rating      genre  year                       released  \
# 0      The Shining      R      Drama  1980  June 13, 1980 (United States)
# 1  The Blue Lagoon      R  Adventure  1980   July 2, 1980 (United States)
#
#    score     votes         director                   writer            star  \
# 0    8.4  927000.0  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8   65000.0   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
#
#           country      budget       gross            company  runtime
# 0  United Kingdom  19000000.0  46998772.0       Warner Bros.    146.0
# 1   United States   4500000.0  58853106.0  Columbia Pictures    104.0

# %%
data_strings = ['name', 'rating', 'genre' ,'year','released','score','votes','director','writer','star','country','budget','gross','company','runtime']

# %% [raw]
# data_dictionary = pd.DataFrame(index=df.columns, columns=[ 'description'])
# data_dictionary

# %%
data_dictionary.loc['name','description'] = 'the name of movie'
data_dictionary.loc['rating','description'] = 'rating of every movie'
data_dictionary.loc['genre','description'] = 'genre of each movie'
data_dictionary.loc['year','description'] = 'year of production'
data_dictionary.loc['released','description'] = 'the year of release'
data_dictionary.loc['score','description'] = 'the score per movie'
data_dictionary.loc['votes','description'] = 'number of votes'
data_dictionary.loc['director','description'] = 'name of the movie director'
data_dictionary.loc['writer','description'] = 'name of the writer'
data_dictionary.loc['star','description'] = 'the actor in the movie'
data_dictionary.loc['country','description'] = 'country of release'
data_dictionary.loc['budget','description'] = 'budget per movie'
data_dictionary.loc['gross','description'] = 'gross per movie'
data_dictionary.loc['company','description'] = 'company of production'
data_dictionary.loc['runtime','description'] = 'runtime for every movie'
data_dictionary
# Out:
#                          description
# name               the name of movie
# rating         rating of every movie
# genre            genre of each movie
# year              year of production
# released         the year of release
# score            the score per movie
# votes                number of votes
# director  name of the movie director
# writer            name of the writer
# star          the actor in the movie
# country           country of release
# budget              budget per movie
# gross                gross per movie
# company        company of production
# runtime      runtime for every movie

# %%
#Importing the Libraries
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Loading the data
df=pd.read_csv(r"C:\Users\maram\Downloads\movies.csv")
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.shape
# Out:
# (7668, 15)

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %% [markdown]
# ## Data Cleaning

# %%
pd.isnull(df).sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
pd.isnull(df).sum()
# Out:
# name        0
# rating      0
# genre       0
# year        0
# released    0
# score       0
# votes       0
# director    0
# writer      0
# star        0
# country     0
# budget      0
# gross       0
# company     0
# runtime     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5421 entries, 0 to 7652
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      5421 non-null   object
#  1   rating    5421 non-null   object
#  2   genre     5421 non-null   object
#  3   year      5421 non-null   int64
#  4   released  5421 non-null   object
#  5   score     5421 non-null   float64
#  6   votes     5421 non-null   float64
#  7   director  5421 non-null   object
#  8   writer    5421 non-null   object
#  9   star      5421 non-null   object
#  10  country   5421 non-null   object
#  11  budget    5421 non-null   float64
#  12  gross     5421 non-null   float64
#  13  company   5421 non-null   object
#  14  runtime   5421 non-null   float64
# dtypes: float64(5), int64(1), object(9)
# memory usage: 677.6+ KB

# %% [markdown]
# ## Finding Correlation

# %%
df['budget']=df['budget'].astype('int64')
df['runtime']=df['runtime'].astype('int64')
df['votes']=df['votes'].astype('int64')
df['gross']=df['gross'].astype('int64')
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
df['yearcorrect'] = df['released'].str.extract(pat = '([0-9]{4})').astype(int)
df
# Out:
#                                                 name     rating      genre  \
# 0                                        The Shining          R      Drama
# 1                                    The Blue Lagoon          R  Adventure
# 2     Star Wars: Episode V - The Empire Strikes Back         PG     Action
# 3                                          Airplane!         PG     Comedy
# 4                                         Caddyshack          R     Comedy
# ...                                              ...        ...        ...
# 7648                               Bad Boys for Life          R     Action
# 7649                              Sonic the Hedgehog         PG     Action
# 7650                                        Dolittle         PG  Adventure
# 7651                            The Call of the Wild         PG  Adventure
# 7652                               The Eight Hundred  Not Rated     Action
#
#       year                           released  score    votes  \
# ...

# %%
df.sort_values(by='gross',inplace=False,ascending=False)
pd.set_option('display.max_rows', None)
df.head(5)
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
#df.drop_duplicates()
#df['company'].drop_duplicates().sort_values(ascending=False)

# %% [markdown]
# ### About the Project

# %%
plt.scatter(x=df['budget'],y=df['gross'])
plt.xlabel=('budget for film')
plt.ylabel('Gross Earnings')
plt.title('Gross vs Budget')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.head(2)
# Out:
#               name rating      genre  year                       released  \
# 0      The Shining      R      Drama  1980  June 13, 1980 (United States)
# 1  The Blue Lagoon      R  Adventure  1980   July 2, 1980 (United States)
#
#    score   votes         director                   writer            star  \
# 0    8.4  927000  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8   65000   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
#
#           country    budget     gross            company  runtime  yearcorrect
# 0  United Kingdom  19000000  46998772       Warner Bros.      146         1980
# 1   United States   4500000  58853106  Columbia Pictures      104         1980

# %%
sns.regplot(x='budget',y='gross',data=df,scatter_kws={"color":"red"},line_kws={"color":"blue"})
# Out:
# <Axes: xlabel='budget', ylabel='gross'>

# %%
df.corr(method='pearson') #pearson(by default) , kendall , spearman
# Out:
# C:\Users\maram\AppData\Local\Temp\ipykernel_10780\3063717695.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method='pearson') #pearson(by default) , kendall , spearman
#                  year     score     votes    budget     gross   runtime  \
# year         1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score        0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes        0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget       0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross        0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime      0.075077  0.414068  0.352303  0.318695  0.275796  1.000000
# yearcorrect  0.998726  0.061923  0.203098  0.320312  0.268721  0.075294
#
#              yearcorrect
# ...

# %%
correlation_matrix=df.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.xlabel=('Movie Features')
plt.ylabel('Movie Features')
plt.title('Correlation Matric for Numeric Features')
plt.show()
# Out:
# C:\Users\maram\AppData\Local\Temp\ipykernel_10780\2631243615.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix=df.corr(method='pearson')

# %%
df.head(2)
# Out:
#               name rating      genre  year                       released  \
# 0      The Shining      R      Drama  1980  June 13, 1980 (United States)
# 1  The Blue Lagoon      R  Adventure  1980   July 2, 1980 (United States)
#
#    score   votes         director                   writer            star  \
# 0    8.4  927000  Stanley Kubrick             Stephen King  Jack Nicholson
# 1    5.8   65000   Randal Kleiser  Henry De Vere Stacpoole  Brooke Shields
#
#           country    budget     gross            company  runtime  yearcorrect
# 0  United Kingdom  19000000  46998772       Warner Bros.      146         1980
# 1   United States   4500000  58853106  Columbia Pictures      104         1980

# %%
df_numerized= df
for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype=='object'):
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes
df_numerized.head(10)
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
# 5  2109       6     10  1980      2502    6.4   123000.0      2528    4362
# 6  5574       6      0  1980      1771    7.9   188000.0      1412     838
# 7  4436       6      3  1980       699    8.2   330000.0      1829    1769
# 8  5281       4      0  1980      1753    6.8   101000.0      2306    1979
# 9  6213       6      3  1980      2286    7.0    10000.0      2864     423
#
#    star  country      budget        gross  company  runtime
# 0  1047       54  19000000.0   46998772.0     2319    146.0
# ...

# %%
correlation_matrix=df_numerized.corr(method='pearson')
annot_kws = {
    'fontsize': 5,  # Set the font size for annotations
}
sns.heatmap(correlation_matrix,annot=True,annot_kws=annot_kws)
plt.xlabel=('Movie Features')
plt.ylabel('Movie Features')
plt.title('Correlation Matric for Numeric Features')
plt.show()

# %%
corr_mat=df_numerized.corr()
corr_pairs=corr_mat.unstack()
corr_pairs.head(10)
# Out:
# name  name        1.000000
#       rating     -0.008069
#       genre       0.016355
#       year        0.011453
#       released   -0.011311
#       score       0.017097
#       votes       0.013088
#       director    0.009079
#       writer      0.009081
#       star        0.006472
# dtype: float64

# %%
for col in df.columns :
    pct_missing=np.mean(df[col].isnull())
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
sorted_pairs=corr_pairs.sort_values()
sorted_pairs.head(10)
# Out:
# genre   budget   -0.368523
# budget  genre    -0.368523
# gross   genre    -0.244101
# genre   gross    -0.244101
# rating  budget   -0.203946
# budget  rating   -0.203946
# rating  gross    -0.181906
# gross   rating   -0.181906
# votes   genre    -0.135990
# genre   votes    -0.135990
# dtype: float64

# %%
high_corr=sorted_pairs[(sorted_pairs)>0.5]
high_corr.head(10)
# Out:
# gross        votes          0.614751
# votes        gross          0.614751
# gross        budget         0.740247
# budget       gross          0.740247
# year         yearcorrect    0.998726
# yearcorrect  year           0.998726
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# dtype: float64

# %% [markdown]
# ###### Votes and Budget have the best correlation to Gross Earnings
